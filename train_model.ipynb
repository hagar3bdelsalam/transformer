# %%
# !git clone https://github.com/hagar3bdelsalam/transformer.git
# %cd transformer

# %%
# !git pull

# %%
# !ls
# Out:
# config.py   model.py	 tokenizer_arz.json  train_model.ipynb	weights
# dataset.py  __pycache__  tokenizer_en.json   train.py

# %%
# !cat train.py

# %%
# !pip install datasets tokenizers tensorboard

# %%
# !ls weights
# Out:
# tmodel_00.pt	       tmodel_07.pt	       tmodel_13_step10500.pt
# tmodel_00_step500.pt   tmodel_07_step5500.pt   tmodel_14.pt
# tmodel_01.pt	       tmodel_07_step6000.pt   tmodel_14_step11000.pt
# tmodel_01_step1000.pt  tmodel_08.pt	       tmodel_14_step11500.pt
# tmodel_01_step1500.pt  tmodel_08_step6500.pt   tmodel_15.pt
# tmodel_02.pt	       tmodel_08_step7000.pt   tmodel_15_step12000.pt
# tmodel_02_step2000.pt  tmodel_09.pt	       tmodel_16.pt
# tmodel_03.pt	       tmodel_09_step7500.pt   tmodel_16_step12500.pt
# tmodel_03_step2500.pt  tmodel_10.pt	       tmodel_16_step13000.pt
# tmodel_03_step3000.pt  tmodel_10_step8000.pt   tmodel_17.pt
# tmodel_04.pt	       tmodel_10_step8500.pt   tmodel_17_step13500.pt
# tmodel_04_step3500.pt  tmodel_11.pt	       tmodel_17_step14000.pt
# tmodel_05.pt	       tmodel_11_step9000.pt   tmodel_18.pt
# tmodel_05_step4000.pt  tmodel_12.pt	       tmodel_18_step14500.pt
# tmodel_05_step4500.pt  tmodel_12_step10000.pt  tmodel_19.pt
# ...

# %%
# !rm -f tokenizer_*.json

# %%
from config import get_config
from train import train_model

# %%
config = get_config()

train_model(config)
# Out:
# using device cuda
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Filtered train: kept 24936 of 25000 rows (64 removed as too long)
# Filtered val: kept 1847 of 1851 rows (4 removed as too long)
# max length of source sentence: 78
# max length of target sentence: 79
# ...
# Processing epoch 19: 100%|██████████| 780/780 [04:05<00:00,  3.17it/s, loss=1.953]
